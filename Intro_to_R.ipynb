# %% [markdown]
# <a href="https://colab.research.google.com/github/JonPaulBIlbao/ML-Finance-DBS/blob/Learning-R/Intro_to_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating vectors

# %% [markdown]
# In order to open a COLAB document using R [click on this link](https://colab.research.google.com/#create=true&language=r,)

# %%
v1=c(1,2,3)

# %%
summary(v)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     1.5     2.0     2.0     2.5     3.0

# %%
v2=c(4,5,6)
