# %% [markdown]
# <a href="https://colab.research.google.com/github/JonPaulBIlbao/ML-Finance-DBS/blob/Learning-R/1_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
v=c(1,2,3)
